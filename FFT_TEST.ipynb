# %%
from INFERENCE_ENGINE_LIB import *
MODEL_NAME = "meta-llama/Llama-3.1-8B-Instruct"
HF_TOKEN = "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"
# Out:
# 2026-03-13 09:22:47.602609: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-13 09:22:47.632271: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-03-13 09:22:48.166994: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
    # 3. Full finetune модель
engine_full = InferenceEngine(
    model_name=MODEL_NAME,
    mode="full",
    full_finetune_path="meta-llama_Llama-3.1-8B-Instruct_full_finetune_epochs_10_learn_len_tok_2048_batch_size_3_save",
    hf_token=HF_TOKEN,
    quantization="4bit",
    device="cuda"
)

answer, lat = engine_full.generate("Мой кариотип 47,XXX[10]/46,XX[15]. Что это значит?")
print(f"Clear ответ: {answer}\nLatency: {lat:.2f}s")
engine_full.unload()
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Some parameters are on the meta device because they were offloaded to the cpu.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Clear ответ: (Кариотип: 47,XXX[10]/46,XX[15])
# Контрольные вопросы
# 1. Что это значит?
# 2. Как это влияет на здоровье?
# 3. Как это влияет на фертильность?
# 4. Как это влияет на риски беременности?
# 5. Как это влияет на риски рождения ребёнка с генетическими нарушениями?
# 6. Как это влияет на риски для ребёнка?
# 7. Как это влияет на риски для матери?
# 8. Как это влияет на риски для потомста?
# 9. Как это влияет на риски для потомства?
# 10. Как это влияет на риски для потомства?
#
# ...
