# %%
from RUN_ALL_LIB import *
import warnings
import gc
import torch
#warnings.filterwarnings("ignore", category=DeprecationWarning)
import os
#os.environ["TRANSFORMERS_VERBOSITY"] = "error"
import logging
#logging.getLogger("transformers").setLevel(logging.ERROR)
#import warnings
#warnings.filterwarnings("ignore", message="Setting `pad_token_id` to `eos_token_id`")

# %%
run_lora(MODEL_LIST[0],
    token="",
    batch_size = 3,
    num_epoch = 20,
    lora_r=32,
    lora_alpha=64, 
    test_trained = None,
    test_status = False,
)
# Out:
# ===== LORA: meta-llama/Llama-3.1-8B-Instruct =====
# ...
# Truncating eval dataset:   0%|          | 0/105 [00:00<?, ? examples/s]
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 128009, 'pad_token_id': 128009}.
#     <div>
#
#       <progress value='1185' max='1185' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1185/1185 1:11:44, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.133965</td>
#       <td>0.096388</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.080937</td>
#       <td>0.065076</td>
#     </tr>
#     <tr>
# ...

# %%
test_list = [
    "meta-llama_Llama-3.1-8B-Instruct_lora_epochs_5_batch_2_optim_adamw_torch_fused_r_16_alpha32",
    "meta-llama_Llama-3.1-8B-Instruct_lora_epochs_5_batch_2_optim_adamw_torch_fused_r_32_alpha64",
    "meta-llama_Llama-3.1-8B-Instruct_lora_epochs_5_batch_4_optim_adamw_torch_fused_r_32_alpha64",
    "meta-llama_Llama-3.1-8B-Instruct_lora_epochs_10_batch_2_optim_adamw_torch_fused_r_16_alpha32",
    "meta-llama_Llama-3.1-8B-Instruct_lora_epochs_10_batch_2_optim_adamw_torch_fused_r_32_alpha64",
    "meta-llama_Llama-3.1-8B-Instruct_lora_epochs_10_batch_4_optim_adamw_torch_fused_r_32_alpha64"
    
]

test_list = [
    "meta-llama_Llama-3.1-8B-Instruct_lora_epochs_15_batch_3_optim_adamw_torch_fused_r_32_alpha64",
    
]

# %%
for k in test_list:
    print(k)
    run_lora(MODEL_LIST[0],
             token="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",
             test_trained = k,
             test_status = False,
    )
    gc.collect()
    torch.cuda.empty_cache()
    gc.collect()
# Out:
# meta-llama_Llama-3.1-8B-Instruct_lora_epochs_15_batch_3_optim_adamw_torch_fused_r_32_alpha64
#
# ===== LORA: meta-llama/Llama-3.1-8B-Instruct =====
# `torch_dtype` is deprecated! Use `dtype` instead!
# ...
# Оценка LoRA: 100%|██████████| 105/105 [21:45<00:00, 12.43s/it]
# /home/timur/miniconda3/lib/python3.13/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /home/timur/miniconda3/lib/python3.13/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# ...
