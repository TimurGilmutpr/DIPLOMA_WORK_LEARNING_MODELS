# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers import BitsAndBytesConfig
import torch
token = "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"
guard_model_id = "meta-llama/Llama-Guard-3-8B"

# %%
#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"
# Загружаем Llama Guard 3-1B (можно 8B, если нужна максимальная точность)

guard_tokenizer = AutoTokenizer.from_pretrained(guard_model_id)
guard_model = AutoModelForCausalLM.from_pretrained(
    guard_model_id,
    torch_dtype=torch.bfloat16,
    device_map="auto",
    token = "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"
)
guard_model.eval()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 #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"
#       2 # Загружаем Llama Guard 3-1B (можно 8B, если нужна максимальная точность)
# ----> 4 guard_tokenizer = AutoTokenizer.from_pretrained(guard_model_id)
#       5 guard_model = AutoModelForCausalLM.from_pretrained(
#       6     guard_model_id,
#       7     torch_dtype=torch.bfloat16,
#       8     device_map="auto",
#       9     token = "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"
#      10 )
#      11 guard_model.eval()
#
# NameError: name 'AutoTokenizer' is not defined

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    #bnb_4bit_compute_dtype=torch.bfloat16,
    #bnb_4bit_use_double_quant=True,
    #bnb_4bit_quant_type="nf4"
)

guard_model = AutoModelForCausalLM.from_pretrained(
    guard_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    token=token
)
# Out:
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
