# %%
import pandas as pd
import os

# %%
vllm_reports_list = [k for k in os.listdir() if k.endswith(".xlsx")]
vllm_reports_list
# Out:
# ['VLLM_TEST_with_metrics_adapter_ruslanmv_Medical-Llama3-8B_lora_epochs_10_batch_2_optim_adamw_torch_fused_r_32_alpha_64_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_ruslanmv_Medical-Llama3-8B_lora_epochs_7_batch_2_optim_paged_adamw_8bit_r_64_alpha_128_lr_1e-05_drop_out_0.0_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_10_batch_3_optim_adamw_torch_fused_r_16_alpha32.xlsx',
#  'VLLM_TEST_with_metrics_adapter_ruslanmv_Medical-Llama3-8B_lora_epochs_5_batch_3_optim_adamw_torch_fused_r_64_alpha_128_lr_0.0001_drop_out_0.1_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_ruslanmv_Medical-Llama3-8B_lora_epochs_7_batch_4_optim_ademamix_r_64_alpha_128_lr_1e-05_drop_out_0.01_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_15_batch_4_optim_adamw_torch_fused_r_16_alpha_32_new_list_of_modules.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_10_batch_2_optim_adamw_torch_fused_r_32_alpha64.xlsx',
#  'VLLM_TEST_with_metrics_adapter_ruslandev_llama-3-8b-gpt-4o-ru1.0_lora_epochs_10_batch_3_optim_adamw_torch_fused_r_64_alpha_128_lr_0.0001_drop_out_0.1_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_15_batch_3_optim_adamw_torch_fused_r_32_alpha64.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_5_batch_3_optim_adamw_torch_fused_r_64_alpha_128_lr_0.0001_drop_out_0.1_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B_with_metrics.xlsx',
#  'VLLM_TEST_with_metrics_clear_model_meta-llama_Llama-3.1-8B-Instruct.xlsx',
#  'VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_10_batch_3_optim_adamw_torch_fused_r_16_alpha_32_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_RAG_ruslandev_llama-3-8b-gpt-4o-ru1.0_with_metrics.xlsx',
#  'VLLM_TEST_with_metrics_adapter_ruslanmv_Medical-Llama3-8B_lora_epochs_10_batch_3_optim_adamw_torch_fused_r_32_alpha_64_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_5_batch_4_optim_adamw_torch_fused_r_32_alpha64.xlsx',
#  'VLLM_TEST_with_metrics_clear_model_meta-llama_Llama-3.1-8B-Instruct_full_finetune_epochs_10_maxlen_1536_bs_3_collator_new_save.xlsx',
#  'VLLM_TEST_with_metrics_adapter_ruslanmv_Medical-Llama3-8B_lora_epochs_10_batch_4_optim_adamw_torch_fused_r_64_alpha_128_lr_0.0002_drop_out_0.05_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_clear_model_meta-llama_Llama-3.1-8B-Instruct_full_finetune_epochs_5_maxlen_1536_bs_3_collator_new_save.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_5_batch_3_optim_adamw_torch_fused_r_32_alpha_64_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_ruslanmv_Medical-Llama3-8B_lora_epochs_5_batch_3_optim_adamw_torch_fused_r_32_alpha_64_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_5_batch_3_optim_adamw_torch_fused_r_16_alpha_32_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_10_batch_4_optim_adamw_torch_fused_r_64_alpha_128_lr_0.0002_drop_out_0.0_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_5_batch_2_optim_adamw_torch_fused_r_32_alpha64.xlsx',
#  'VLLM_TEST_with_metrics_clear_model_ruslandev_llama-3-8b-gpt-4o-ru1.0.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_10_batch_4_optim_adamw_torch_fused_r_32_alpha64.xlsx',
#  'VLLM_TEST_with_metrics_adapter_ruslanmv_Medical-Llama3-8B_lora_epochs_5_batch_2_optim_adamw_torch_fused_r_32_alpha_64_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_10_batch_4_optim_adamw_torch_fused_r_64_alpha_128_lr_0.0002_drop_out_0.05_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_ruslandev_llama-3-8b-gpt-4o-ru1.0_lora_epochs_10_batch_2_optim_adamw_torch_fused_r_16_alpha_32_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_ruslanmv_Medical-Llama3-8B_lora_epochs_10_batch_2_optim_adamw_torch_fused_r_64_alpha_64_lr_0.0005_drop_out_0.05_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_ruslanmv_Medical-Llama3-8B_lora_epochs_10_batch_3_optim_adamw_torch_fused_r_16_alpha_32_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_5_batch_2_optim_adamw_torch_fused_r_16_alpha32.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_10_batch_4_optim_ademamix_r_16_alpha_32_lr_1e-05_drop_out_0.01_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_ruslanmv_Medical-Llama3-8B_lora_epochs_10_batch_2_optim_adamw_torch_fused_r_16_alpha_32_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_10_batch_3_optim_adamw_torch_fused_r_16_alpha_32_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens.xlsx',
#  'VLLM_TEST_with_metrics_clear_model_ruslanmv_Medical-Llama3-8B.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_10_batch_3_optim_adamw_torch_fused_r_64_alpha_128_lr_0.0001_drop_out_0.1_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_ruslanmv_Medical-Llama3-8B_lora_epochs_10_batch_2_optim_adamw_torch_fused_r_64_alpha_128_lr_0.0005_drop_out_0.05_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_10_batch_4_optim_ademamix_r_64_alpha_128_lr_0.0002_drop_out_0.05_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_10_batch_2_optim_adamw_torch_fused_r_16_alpha_32_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_10_batch_4_optim_adamw_torch_fused_r_16_alpha_32_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_10_batch_3_optim_adamw_torch_fused_r_32_alpha_64_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_10_batch_2_optim_adamw_torch_fused_r_16_alpha32.xlsx',
#  'VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_7_batch_2_optim_adamw_torch_fused_r_64_alpha_128_lr_1e-05_drop_out_0.0_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx']

# %%
df = pd.read_excel(vllm_reports_list[0])
df["Adapter_name"] = vllm_reports_list[0]
df
# Out:
#                                                 Promts  \
# 0    Мой кариотип 46,XX,t(9;13)(p11;q21). Что это з...
# 1    Мой кариотип 46,XX,inv(17)(q32q33). Что это зн...
# 2    Мой кариотип 47,XX,+8[10]/46,XX[15]. Что это з...
# 3               Мой кариотип 49,XXXXY. Что это значит?
# 4    Мой кариотип 45,XY,der(22;22)(q10;q10). Что эт...
# ..                                                 ...
# 100  Мой кариотип 45,XY,der(21;22)(q10;q10). Что эт...
# 101    Мой кариотип 47,XX,+i(12)(p10). Что это значит?
# 102    Мой кариотип 46,XX,del(8)(p22). Что это значит?
# 103  Мой кариотип 46,XX,del(3)(q29q29). Что это зна...
# 104    Мой кариотип 47,XX,+i(12)(p10). Что это значит?
#
#                                             References  \
# 0    Тип перестройки: сбалансированная реципрокная ...
# 1    Кариотип: 46,XX,inv(17)(q32q33)\nТип хромосомн...
# 2    Кариотип: 47,XX,+8[10]/46,XX[15]\nТип хромосом...
# 3    Кариотип: 49,XXXXY\nТип хромосомной аномалии: ...
# 4    Кариотип: 45,XY,der(22;22)(q10;q10)\nТип перес...
# ..                                                 ...
# 100  Тип перестройки: сбалансированная Робертсоновс...
# 101  Кариотип: 47,XX,+i(12)(p10)\nТип: изохромосома...
# 102  Кариотип: 46,XX,del(8)(p22)\nТип хромосомной а...
# 103  Кариотип: 46,XX,del(3)(q29q29)\nТип хромосомно...
# 104  Кариотип: 47,XX,+i(12)(p10)\nТип: изохромосома...
#
#                                                Answers  Response times  \
# 0    Тип перестройки: сбалансированная реципрокная ...       12.547933
# 1    Кариотип: 46,XX,inv(17)(q32q33)\nТип хромосомн...        8.359145
# 2    Кариотип: 47,XX,+8[10]/46,XX[15]\nТип хромосом...        6.524995
# 3    Кариотип: 49,XXXXY\nТип хромосомной аномалии: ...        1.255999
# 4    Кариотип: 45,XY,der(22;22)(q10;q10)\nТип перес...       12.151929
# ..                                                 ...             ...
# 100  Тип перестройки: сбалансированная Робертсоновс...        8.665933
# 101  Кариотип: 47,XX,+i(12)(p10)\nТип: изохромосома...        2.245860
# 102  Кариотип: 46,XX,del(8)(p22)\nТип хромосомной а...        4.134601
# 103  Кариотип: 46,XX,del(3)(q29q29)\nТип хромосомно...        3.006369
# 104  Кариотип: 47,XX,+i(12)(p10)\nТип: изохромосома...        2.243558
#
#      Completion tokens  Tokens per second  Exact Match      BLEU   ROUGE-L  \
# 0                 1128          89.895286            0  0.596670  0.914286
# 1                  761          91.038015            1  1.000000  1.000000
# 2                  595          91.187813            1  1.000000  1.000000
# 3                  114          90.764407            0  0.266476  0.666667
# 4                 1104          90.849772            0  0.869651  0.961039
# ..                 ...                ...          ...       ...       ...
# 100                784          90.469193            1  1.000000  1.000000
# 101                203          90.388553            1  1.000000  1.000000
# 102                374          90.456131            1  1.000000  1.000000
# 103                272          90.474577            0  0.715783  0.944444
# 104                203          90.481269            1  1.000000  1.000000
#
#        METEOR  BERTScore F1                                       Adapter_name
# 0    0.708154      0.953043  VLLM_TEST_with_metrics_adapter_ruslanmv_Medica...
# 1    1.000000      1.000000  VLLM_TEST_with_metrics_adapter_ruslanmv_Medica...
# 2    1.000000      1.000000  VLLM_TEST_with_metrics_adapter_ruslanmv_Medica...
# 3    0.490839      0.816395  VLLM_TEST_with_metrics_adapter_ruslanmv_Medica...
# 4    0.877318      1.000000  VLLM_TEST_with_metrics_adapter_ruslanmv_Medica...
# ..        ...           ...                                                ...
# 100  1.000000      1.000000  VLLM_TEST_with_metrics_adapter_ruslanmv_Medica...
# 101  0.999997      1.000000  VLLM_TEST_with_metrics_adapter_ruslanmv_Medica...
# 102  1.000000      1.000000  VLLM_TEST_with_metrics_adapter_ruslanmv_Medica...
# 103  0.824202      0.922080  VLLM_TEST_with_metrics_adapter_ruslanmv_Medica...
# 104  0.999997      1.000000  VLLM_TEST_with_metrics_adapter_ruslanmv_Medica...
#
# [105 rows x 12 columns]

# %%
dfs_list = []
for i in range(len(vllm_reports_list)):
    df = pd.read_excel(vllm_reports_list[i])
    df["Adapter_name"] = vllm_reports_list[i]
    dfs_list.append(df)
dfs_all = pd.concat(dfs_list, ignore_index = True)
dfs_all.shape
# Out:
# (4725, 18)

# %%
print("Всего записей:", dfs_all.shape[0])
print("Уникальных адаптеров:", dfs_all['Adapter_name'].nunique())
print("Количество тестов на адаптер:\n", dfs_all['Adapter_name'].value_counts().head())
# Out:
# Всего записей: 4725
# Уникальных адаптеров: 45
# Количество тестов на адаптер:
#  Adapter_name
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical-Llama3-8B_lora_epochs_10_batch_2_optim_adamw_torch_fused_r_32_alpha_64_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx                           105
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical-Llama3-8B_lora_epochs_7_batch_2_optim_paged_adamw_8bit_r_64_alpha_128_lr_1e-05_drop_out_0.0_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx      105
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama-3.1-8B-Instruct_lora_epochs_10_batch_3_optim_adamw_torch_fused_r_16_alpha32.xlsx                                                                                                   105
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical-Llama3-8B_lora_epochs_5_batch_3_optim_adamw_torch_fused_r_64_alpha_128_lr_0.0001_drop_out_0.1_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx    105
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical-Llama3-8B_lora_epochs_7_batch_4_optim_ademamix_r_64_alpha_128_lr_1e-05_drop_out_0.01_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx             105
# Name: count, dtype: int64

# %%
# Ячейка 2
quality = ['Exact Match', 'BLEU', 'ROUGE-L', 'METEOR', 'BERTScore F1']
performance = ['Response times', 'Completion tokens', 'Tokens per second']

print("=== ОБЩАЯ СТАТИСТИКА ===")
print(dfs_all[quality+performance].describe())

print("\n=== ПЕРЦЕНТИЛИ ДЛЯ КАЧЕСТВА ===")
for p in [0.1, 0.25, 0.5, 0.75, 0.9, 0.95, 0.99]:
    print(f"\n{p*100:5.0f}%:")
    for m in quality:
        val = dfs_all[m].quantile(p)
        print(f"   {m:12s} : {val:.4f}")
# Out:
# === ОБЩАЯ СТАТИСТИКА ===
#        Exact Match         BLEU      ROUGE-L       METEOR  BERTScore F1  \
# count  4410.000000  4410.000000  4410.000000  4410.000000   4410.000000
# mean      0.391383     0.631793     0.793602     0.693881      0.901447
# std       0.488115     0.419613     0.281574     0.366381      0.131455
# min       0.000000     0.000000     0.008466     0.000000      0.439801
# 25%       0.000000     0.091302     0.549763     0.298465      0.777388
# 50%       0.000000     0.867656     0.990654     0.892329      0.991782
# 75%       1.000000     1.000000     1.000000     1.000000      1.000000
# max       1.000000     1.000000     1.000000     1.000000      1.000000
#
#        Response times  Completion tokens  Tokens per second
# count     4725.000000        4725.000000        4725.000000
# mean         7.692669         721.954286          93.739920
# std          4.766534         449.762258           2.471368
# min          0.170552          16.000000          53.402939
# 25%          3.865596         359.000000          90.750002
# 50%          6.817049         642.000000          95.394838
# 75%         10.862871        1013.000000          95.630330
# max         17.796469        1600.000000          97.143146
#
# === ПЕРЦЕНТИЛИ ДЛЯ КАЧЕСТВА ===
#
#    10%:
#    Exact Match  : 0.0000
#    BLEU         : 0.0041
#    ROUGE-L      : 0.3333
#    METEOR       : 0.0928
#    BERTScore F1 : 0.6988
#
#    25%:
#    Exact Match  : 0.0000
#    BLEU         : 0.0913
#    ROUGE-L      : 0.5498
#    METEOR       : 0.2985
#    BERTScore F1 : 0.7774
#
#    50%:
#    Exact Match  : 0.0000
#    BLEU         : 0.8677
#    ROUGE-L      : 0.9907
#    METEOR       : 0.8923
#    BERTScore F1 : 0.9918
#
#    75%:
#    Exact Match  : 1.0000
#    BLEU         : 1.0000
#    ROUGE-L      : 1.0000
#    METEOR       : 1.0000
#    BERTScore F1 : 1.0000
#
#    90%:
#    Exact Match  : 1.0000
#    BLEU         : 1.0000
#    ROUGE-L      : 1.0000
#    METEOR       : 1.0000
#    BERTScore F1 : 1.0000
#
#    95%:
#    Exact Match  : 1.0000
#    BLEU         : 1.0000
#    ROUGE-L      : 1.0000
#    METEOR       : 1.0000
#    BERTScore F1 : 1.0000
#
#    99%:
#    Exact Match  : 1.0000
#    BLEU         : 1.0000
#    ROUGE-L      : 1.0000
#    METEOR       : 1.0000
#    BERTScore F1 : 1.0000

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Настройки графиков
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 12

# %%
# Данные уже загружены в dfs_all (из предыдущих ячеек)
# Проверим размер и состав
print("Размер данных:", dfs_all.shape)
print("\nПервые 2 строки:")
dfs_all.head(2)
# Out:
# Размер данных: (4725, 18)
#
# Первые 2 строки:
#                                               Promts  \
# 0  Мой кариотип 46,XX,t(9;13)(p11;q21). Что это з...
# 1  Мой кариотип 46,XX,inv(17)(q32q33). Что это зн...
#
#                                           References  \
# 0  Тип перестройки: сбалансированная реципрокная ...
# 1  Кариотип: 46,XX,inv(17)(q32q33)\nТип хромосомн...
#
#                                              Answers  Response times  \
# 0  Тип перестройки: сбалансированная реципрокная ...       12.547933
# 1  Кариотип: 46,XX,inv(17)(q32q33)\nТип хромосомн...        8.359145
#
#    Completion tokens  Tokens per second  Exact Match     BLEU   ROUGE-L  \
# 0               1128          89.895286          0.0  0.59667  0.914286
# 1                761          91.038015          1.0  1.00000  1.000000
#
#      METEOR  BERTScore F1                                       Adapter_name  \
# 0  0.708154      0.953043  VLLM_TEST_with_metrics_adapter_ruslanmv_Medica...
# 1  1.000000      1.000000  VLLM_TEST_with_metrics_adapter_ruslanmv_Medica...
#
#   Answers_RAG  exact_match  bleu  rouge_l  meteor  bertscore_f1
# 0         NaN          NaN   NaN      NaN     NaN           NaN
# 1         NaN          NaN   NaN      NaN     NaN           NaN

# %%
# Убедимся, что нет пропусков в ключевых метриках
print("Пропуски:\n", dfs_all[['Exact Match', 'BLEU', 'ROUGE-L', 'METEOR', 'BERTScore F1', 
                              'Response times', 'Tokens per second']].isnull().sum())
# Out:
# Пропуски:
#  Exact Match          315
# BLEU                 315
# ROUGE-L              315
# METEOR               315
# BERTScore F1         315
# Response times         0
# Tokens per second      0
# dtype: int64

# %%
# Основные статистики для всех метрик
metrics = ['Exact Match', 'BLEU', 'ROUGE-L', 'METEOR', 'BERTScore F1', 
           'Response times', 'Completion tokens', 'Tokens per second']
desc_all = dfs_all[metrics].describe(percentiles=[0.01, 0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 0.95, 0.99])
desc_all
# Out:
#        Exact Match         BLEU      ROUGE-L       METEOR  BERTScore F1  \
# count  4410.000000  4410.000000  4410.000000  4410.000000   4410.000000
# mean      0.391383     0.631793     0.793602     0.693881      0.901447
# std       0.488115     0.419613     0.281574     0.366381      0.131455
# min       0.000000     0.000000     0.008466     0.000000      0.439801
# 1%        0.000000     0.000000     0.097595     0.003640      0.539836
# 5%        0.000000     0.001332     0.256082     0.059915      0.658874
# 10%       0.000000     0.004121     0.333333     0.092815      0.698831
# 25%       0.000000     0.091302     0.549763     0.298465      0.777388
# 50%       0.000000     0.867656     0.990654     0.892329      0.991782
# 75%       1.000000     1.000000     1.000000     1.000000      1.000000
# 90%       1.000000     1.000000     1.000000     1.000000      1.000000
# 95%       1.000000     1.000000     1.000000     1.000000      1.000000
# 99%       1.000000     1.000000     1.000000     1.000000      1.000000
# max       1.000000     1.000000     1.000000     1.000000      1.000000
#
#        Response times  Completion tokens  Tokens per second
# count     4725.000000        4725.000000        4725.000000
# mean         7.692669         721.954286          93.739920
# std          4.766534         449.762258           2.471368
# min          0.170552          16.000000          53.402939
# 1%           0.299175          26.000000          90.339281
# 5%           1.896580         181.000000          90.469009
# 10%          2.570441         246.000000          90.543844
# 25%          3.865596         359.000000          90.750002
# 50%          6.817049         642.000000          95.394838
# 75%         10.862871        1013.000000          95.630330
# 90%         16.760608        1600.000000          95.774149
# 95%         16.940391        1600.000000          95.866911
# 99%         17.295772        1600.000000          96.051322
# max         17.796469        1600.000000          97.143146

# %%
fig, axes = plt.subplots(2, 4, figsize=(16, 10))
axes = axes.flatten()

for i, metric in enumerate(metrics):
    sns.histplot(dfs_all[metric], bins=50, kde=True, ax=axes[i], color='skyblue')
    axes[i].set_title(f'Распределение {metric}')
    axes[i].set_xlabel(metric)

plt.tight_layout()
plt.show()

# %%
# Группировка по имени адаптера
adapter_stats = dfs_all.groupby('Adapter_name')[metrics].agg(['mean', 'median', 'std', 'min', 'max'])
adapter_stats.head()
# Out:
#                                                    Exact Match         \
#                                                           mean median
# Adapter_name
# VLLM_TEST_RAG_ruslandev_llama-3-8b-gpt-4o-ru1.0...         NaN    NaN
# VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B.xlsx              NaN    NaN
# VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B_with_m...         NaN    NaN
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...     0.00000    0.0
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...     0.67619    1.0
#
#                                                                         \
#                                                          std  min  max
# Adapter_name
# VLLM_TEST_RAG_ruslandev_llama-3-8b-gpt-4o-ru1.0...       NaN  NaN  NaN
# VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B.xlsx            NaN  NaN  NaN
# VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B_with_m...       NaN  NaN  NaN
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  0.000000  0.0  0.0
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  0.470173  0.0  1.0
#
#                                                         BLEU            \
#                                                         mean    median
# Adapter_name
# VLLM_TEST_RAG_ruslandev_llama-3-8b-gpt-4o-ru1.0...       NaN       NaN
# VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B.xlsx            NaN       NaN
# VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B_with_m...       NaN       NaN
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  0.335455  0.134369
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  0.914860  1.000000
#
#                                                                         \
#                                                          std       min
# Adapter_name
# VLLM_TEST_RAG_ruslandev_llama-3-8b-gpt-4o-ru1.0...       NaN       NaN
# VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B.xlsx            NaN       NaN
# VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B_with_m...       NaN       NaN
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  0.350692  0.000781
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  0.184604  0.000720
#
#                                                               ...  \
#                                                          max  ...
# Adapter_name                                                  ...
# VLLM_TEST_RAG_ruslandev_llama-3-8b-gpt-4o-ru1.0...       NaN  ...
# VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B.xlsx            NaN  ...
# VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B_with_m...       NaN  ...
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  0.946921  ...
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  1.000000  ...
#
#                                                    Completion tokens          \
#                                                                 mean  median
# Adapter_name
# VLLM_TEST_RAG_ruslandev_llama-3-8b-gpt-4o-ru1.0...        524.885714   493.0
# VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B.xlsx            1600.000000  1600.0
# VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B_with_m...       1600.000000  1600.0
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...        782.238095   679.0
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...        608.942857   589.0
#
#                                                                             \
#                                                            std   min   max
# Adapter_name
# VLLM_TEST_RAG_ruslandev_llama-3-8b-gpt-4o-ru1.0...  335.119534    22  1600
# VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B.xlsx         0.000000  1600  1600
# VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B_with_m...    0.000000  1600  1600
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  476.899633   103  1600
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  321.096823   109  1242
#
#                                                    Tokens per second  \
#                                                                 mean
# Adapter_name
# VLLM_TEST_RAG_ruslandev_llama-3-8b-gpt-4o-ru1.0...         92.277250
# VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B.xlsx              93.951282
# VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B_with_m...         93.951282
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...         90.639621
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...         90.522527
#
#                                                                          \
#                                                        median       std
# Adapter_name
# VLLM_TEST_RAG_ruslandev_llama-3-8b-gpt-4o-ru1.0...  93.555638  5.094285
# VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B.xlsx       93.968446  0.453231
# VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B_with_m...  93.968446  0.453231
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  90.620065  0.168019
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  90.506724  0.147651
#
#
#                                                           min        max
# Adapter_name
# VLLM_TEST_RAG_ruslandev_llama-3-8b-gpt-4o-ru1.0...  69.236190  94.966706
# VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B.xlsx       92.180113  94.903407
# VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B_with_m...  92.180113  94.903407
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  89.905474  91.019543
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  89.789553  91.110830
#
# [5 rows x 40 columns]

# %%
# Добавим также 95-й перцентиль для времени ответа (чтобы оценить долгие хвосты)
percentile_95 = dfs_all.groupby('Adapter_name')['Response times'].quantile(0.95)
adapter_stats[('Response times', 'p95')] = percentile_95

# И долю точных совпадений (Exact Match = 1)
exact_rate = dfs_all.groupby('Adapter_name')['Exact Match'].mean()
adapter_stats[('Exact Match', 'rate')] = exact_rate

adapter_stats.sort_values(('Exact Match', 'rate'), ascending=False).head(10)
# Out:
#                                                    Exact Match         \
#                                                           mean median
# Adapter_name
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...    0.695238    1.0
# VLLM_TEST_with_metrics_adapter_ruslandev_llama-...    0.685714    1.0
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...    0.685714    1.0
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...    0.685714    1.0
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...    0.685714    1.0
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...    0.676190    1.0
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...    0.676190    1.0
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...    0.676190    1.0
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...    0.666667    1.0
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...    0.657143    1.0
#
#                                                                         \
#                                                          std  min  max
# Adapter_name
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  0.462514  0.0  1.0
# VLLM_TEST_with_metrics_adapter_ruslandev_llama-...  0.466457  0.0  1.0
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  0.466457  0.0  1.0
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  0.466457  0.0  1.0
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  0.466457  0.0  1.0
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  0.470173  0.0  1.0
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  0.470173  0.0  1.0
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  0.470173  0.0  1.0
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  0.473665  0.0  1.0
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  0.476941  0.0  1.0
#
#                                                         BLEU                   \
#                                                         mean median       std
# Adapter_name
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  0.897479    1.0  0.224777
# VLLM_TEST_with_metrics_adapter_ruslandev_llama-...  0.911914    1.0  0.197075
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  0.913946    1.0  0.192362
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  0.891589    1.0  0.225212
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  0.908656    1.0  0.208405
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  0.898241    1.0  0.212446
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  0.914860    1.0  0.184604
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  0.906150    1.0  0.216917
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  0.897250    1.0  0.225225
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  0.910352    1.0  0.188402
#
#                                                                   ...  \
#                                                         min  max  ...
# Adapter_name                                                      ...
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  0.00072  1.0  ...
# VLLM_TEST_with_metrics_adapter_ruslandev_llama-...  0.00072  1.0  ...
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  0.00072  1.0  ...
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  0.00072  1.0  ...
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  0.00072  1.0  ...
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  0.00072  1.0  ...
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  0.00072  1.0  ...
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  0.00072  1.0  ...
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  0.00072  1.0  ...
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  0.00072  1.0  ...
#
#                                                    Completion tokens       \
#                                                                  std  min
# Adapter_name
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...        305.540603  114
# VLLM_TEST_with_metrics_adapter_ruslandev_llama-...        317.363826  109
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...        315.392424  114
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...        323.667206  114
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...        309.042908  114
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...        320.199191  114
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...        321.096823  109
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...        319.156506  112
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...        307.208955  109
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...        315.111461  119
#
#                                                          Tokens per second  \
#                                                      max              mean
# Adapter_name
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  1482         95.641674
# VLLM_TEST_with_metrics_adapter_ruslandev_llama-...  1253         90.675178
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  1221         90.476157
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  1600         90.524185
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  1203         95.491809
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  1414         90.558452
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  1242         90.522527
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  1303         95.845810
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  1159         95.698242
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  1227         95.678708
#
#                                                                          \
#                                                        median       std
# Adapter_name
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  95.592847  0.278922
# VLLM_TEST_with_metrics_adapter_ruslandev_llama-...  90.659906  0.115766
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  90.461558  0.168154
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  90.530460  0.109428
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  95.507134  0.114364
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  90.538229  0.145171
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  90.506724  0.147651
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  95.805307  0.249189
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  95.670144  0.154728
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  95.692324  0.139359
#
#                                                                           \
#                                                           min        max
# Adapter_name
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  94.564570  97.047628
# VLLM_TEST_with_metrics_adapter_ruslandev_llama-...  90.114717  91.153544
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  89.814040  91.124857
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  90.012250  90.864939
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  94.714515  95.898085
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  89.895286  91.187813
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  89.789553  91.110830
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  94.833030  97.143146
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  95.194688  96.308680
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  94.558902  96.089756
#
#                                                    Response times Exact Match
#                                                               p95        rate
# Adapter_name
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...      10.813554    0.695238
# VLLM_TEST_with_metrics_adapter_ruslandev_llama-...      12.785862    0.685714
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...      12.510848    0.685714
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...      12.142380    0.685714
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...      11.221782    0.685714
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...      12.472813    0.676190
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...      13.373902    0.676190
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...      11.644611    0.676190
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...      11.564434    0.666667
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...      11.894200    0.657143
#
# [10 rows x 42 columns]

# %%
top_adapters = adapter_stats.nlargest(10, ('Exact Match', 'rate')).index
top_data = dfs_all[dfs_all['Adapter_name'].isin(top_adapters)]

plt.figure(figsize=(14, 6))
sns.boxplot(data=top_data, x='Adapter_name', y='Exact Match')
plt.xticks(rotation=45, ha='right')
plt.title('Распределение Exact Match среди лучших адаптеров')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_181278/368124274.py:8: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# Top-10 по BLEU
top_bleu = adapter_stats.nlargest(10, ('BLEU', 'mean')).index
sns.boxplot(data=dfs_all[dfs_all['Adapter_name'].isin(top_bleu)], x='Adapter_name', y='BLEU', ax=ax1)
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, ha='right')
ax1.set_title('Top-10 по среднему BLEU')

# Top-10 по ROUGE-L
top_rouge = adapter_stats.nlargest(10, ('ROUGE-L', 'mean')).index
sns.boxplot(data=dfs_all[dfs_all['Adapter_name'].isin(top_rouge)], x='Adapter_name', y='ROUGE-L', ax=ax2)
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45, ha='right')
ax2.set_title('Top-10 по среднему ROUGE-L')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_181278/2230009559.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, ha='right')
# /tmp/ipykernel_181278/2230009559.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45, ha='right')
# /tmp/ipykernel_181278/2230009559.py:15: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# Сводная таблица средних значений для каждого адаптера
mean_metrics = dfs_all.groupby('Adapter_name')[['BLEU', 'ROUGE-L', 'METEOR', 'BERTScore F1', 
                                                 'Exact Match', 'Tokens per second']].mean()

plt.figure(figsize=(10, 8))
scatter = plt.scatter(mean_metrics['Tokens per second'], mean_metrics['BLEU'], 
                      c=mean_metrics['Exact Match'], cmap='viridis', s=100, alpha=0.7)
plt.colorbar(scatter, label='Exact Match (средний)')
plt.xlabel('Средняя скорость (токен/сек)')
plt.ylabel('Средний BLEU')
plt.title('Скорость генерации против качества (BLEU)')
for label in mean_metrics.index:
    plt.annotate(label[:15], (mean_metrics.loc[label, 'Tokens per second'], 
                              mean_metrics.loc[label, 'BLEU']), fontsize=8)
plt.tight_layout()
plt.show()

# %%
corr = dfs_all[metrics].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Корреляция метрик качества и эффективности')
plt.show()

# %%
# Нормализуем метрики (min-max) для каждого адаптера
norm_metrics = mean_metrics[['Exact Match', 'BLEU', 'ROUGE-L']].copy()
for col in norm_metrics.columns:
    norm_metrics[col] = (norm_metrics[col] - norm_metrics[col].min()) / (norm_metrics[col].max() - norm_metrics[col].min())

# Интегральный рейтинг (1 = лучший)
norm_metrics['score'] = (0.4 * norm_metrics['Exact Match'] + 
                         0.3 * norm_metrics['BLEU'] + 
                         0.3 * norm_metrics['ROUGE-L'])

# Учитываем стабильность: коэффициент вариации для Exact Match (чем меньше, тем лучше)
cv_exact = dfs_all.groupby('Adapter_name')['Exact Match'].std() / (dfs_all.groupby('Adapter_name')['Exact Match'].mean() + 1e-6)
norm_cv = 1 - (cv_exact - cv_exact.min()) / (cv_exact.max() - cv_exact.min())  # инвертируем

norm_metrics['final_score'] = 0.8 * norm_metrics['score'] + 0.2 * norm_cv

# Сортируем
ranking = norm_metrics.sort_values('final_score', ascending=False)
ranking[['Exact Match', 'BLEU', 'ROUGE-L', 'score', 'final_score']].head(10)
# Out:
#                                                     Exact Match      BLEU  \
# Adapter_name
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...     0.986301  0.999001
# VLLM_TEST_with_metrics_adapter_ruslandev_llama-...     0.986301  0.996779
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...     1.000000  0.980998
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...     0.986301  0.993217
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...     0.972603  1.000000
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...     0.972603  0.990478
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...     0.986301  0.974559
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...     0.972603  0.981831
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...     0.945205  0.995071
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...     0.945205  0.992113
#
#                                                      ROUGE-L     score  \
# Adapter_name
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  0.992661  0.992019
# VLLM_TEST_with_metrics_adapter_ruslandev_llama-...  0.991302  0.990945
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  0.982222  0.988966
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  0.989112  0.989219
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  1.000000  0.989041
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  0.985930  0.981963
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  0.980839  0.981140
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  0.989340  0.980392
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...  0.998072  0.976025
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...  0.994604  0.974097
#
#                                                     final_score
# Adapter_name
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...     0.980337
# VLLM_TEST_with_metrics_adapter_ruslandev_llama-...     0.979477
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...     0.978187
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...     0.978097
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...     0.977660
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...     0.971998
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...     0.971633
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...     0.970741
# VLLM_TEST_with_metrics_adapter_meta-llama_Llama...     0.966653
# VLLM_TEST_with_metrics_adapter_ruslanmv_Medical...     0.965111

# %%
# Покажем лучший адаптер и его параметры
best_adapter = ranking.index[0]
print(f"Лучший адаптер: {best_adapter}\n")
print("Его средние метрики:")
mean_metrics.loc[best_adapter]
# Out:
# Лучший адаптер: VLLM_TEST_with_metrics_adapter_ruslanmv_Medical-Llama3-8B_lora_epochs_10_batch_2_optim_adamw_torch_fused_r_16_alpha_32_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx
#
# Его средние метрики:
# BLEU                  0.913946
# ROUGE-L               0.967861
# METEOR                0.929353
# BERTScore F1          0.987035
# Exact Match           0.685714
# Tokens per second    90.476157
# Name: VLLM_TEST_with_metrics_adapter_ruslanmv_Medical-Llama3-8B_lora_epochs_10_batch_2_optim_adamw_torch_fused_r_16_alpha_32_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx, dtype: float64

# %%
# Сравним лучшего с худшим по Exact Match
worst_adapter = ranking.index[-1]
print(f"Худший адаптер (по интегральной оценке): {worst_adapter}\n")
print("Средние метрики худшего:")
mean_metrics.loc[worst_adapter]
# Out:
# Худший адаптер (по интегральной оценке): VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B_with_metrics.xlsx
#
# Средние метрики худшего:
# BLEU                       NaN
# ROUGE-L                    NaN
# METEOR                     NaN
# BERTScore F1               NaN
# Exact Match                NaN
# Tokens per second    93.951282
# Name: VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B_with_metrics.xlsx, dtype: float64

# %%
best_data = dfs_all[dfs_all['Adapter_name'] == best_adapter]

fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.flatten()

plot_metrics = ['Exact Match', 'BLEU', 'ROUGE-L', 'METEOR', 'BERTScore F1', 'Tokens per second']
for i, metric in enumerate(plot_metrics):
    sns.histplot(best_data[metric], bins=20, kde=True, ax=axes[i], color='green')
    axes[i].set_title(f'{metric} для лучшего адаптера')
    axes[i].axvline(best_data[metric].mean(), color='red', linestyle='--', label=f'mean={best_data[metric].mean():.3f}')
    axes[i].legend()

plt.tight_layout()
plt.show()

# %%
best_adapter
# Out:
# 'VLLM_TEST_with_metrics_adapter_ruslanmv_Medical-Llama3-8B_lora_epochs_10_batch_2_optim_adamw_torch_fused_r_16_alpha_32_q_proj_v_proj_k_proj_o_proj_gate_proj_up_proj_down_proj_embed_tokens_lm_head.xlsx'

# %%
worst_data = dfs_all[dfs_all['Adapter_name'] == worst_adapter]

fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.flatten()

plot_metrics = ['Exact Match', 'BLEU', 'ROUGE-L', 'METEOR', 'BERTScore F1', 'Tokens per second']
for i, metric in enumerate(plot_metrics):
    sns.histplot(worst_data[metric], bins=20, kde=True, ax=axes[i], color='green')
    axes[i].set_title(f'{metric} для худчшего адаптера')
    axes[i].axvline(worst_data[metric].mean(), color='red', linestyle='--', label=f'mean={worst_data[metric].mean():.3f}')
    axes[i].legend()

plt.tight_layout()
plt.show()

# %%
worst_adapter
# Out:
# 'VLLM_TEST_RAG_ruslanmv_Medical-Llama3-8B_with_metrics.xlsx'

# %%
# Выводы по лучшему адаптеру
print("Оценка лучшего адаптера:")
print(f"- Exact Match достигается в {best_data['Exact Match'].mean()*100:.1f}% случаев")
print(f"- Средний BLEU: {best_data['BLEU'].mean():.3f}")
print(f"- Средний ROUGE-L: {best_data['ROUGE-L'].mean():.3f}")
print(f"- Медианное время ответа: {best_data['Response times'].median():.2f} сек")
print(f"- Скорость генерации: {best_data['Tokens per second'].mean():.1f} токен/сек")
print(f"- Стабильность (ст.откл. Exact Match): {best_data['Exact Match'].std():.3f}")
# Out:
# Оценка лучшего адаптера:
# - Exact Match достигается в 68.6% случаев
# - Средний BLEU: 0.914
# - Средний ROUGE-L: 0.968
# - Медианное время ответа: 6.58 сек
# - Скорость генерации: 90.5 токен/сек
# - Стабильность (ст.откл. Exact Match): 0.466

# %%
# Анализ: корреляция длины ответа с качеством для лучшего адаптера
plt.figure(figsize=(8, 6))
sns.scatterplot(data=best_data, x='Completion tokens', y='BLEU', alpha=0.6)
plt.title('Зависимость BLEU от числа сгенерированных токенов (лучший адаптер)')
plt.xlabel('Completion tokens')
plt.ylabel('BLEU')
plt.show()
